# %%
import pandas as pd
import datetime as dt

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  14.6  1.0  0.0   0.0
# 1  Leicester City  ...  Match Report    NaN  19.0  7.0  13.0  0.0  0.0   0.0
# 2     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.8  0.0  0.0   0.0
# 3          Fulham  ...  Match Report    NaN  22.0  8.0  15.5  1.0  0.0   0.0
# 4     Aston Villa  ...  Match Report    NaN  22.0  8.0  16.3  1.0  0.0   0.0
#
#    season     team
# ...

# %%
matches.shape
# Out:
# (1012, 27)

# %%
matches["team"].value_counts()
# Out:
# West Ham United             51
# Tottenham Hotspur           51
# Wolverhampton Wanderers     51
# Leicester City              51
# Newcastle United            51
# Brentford                   51
# Everton                     51
# Southampton                 51
# Aston Villa                 51
# Leeds United                50
# Chelsea                     50
# Manchester United           50
# Crystal Palace              50
# Arsenal                     50
# Manchester City             50
# Brighton and Hove Albion    50
# Liverpool                   50
# Norwich City                38
# Watford                     38
# Burnley                     38
# Fulham                      13
# Bournemouth                 13
# Nottingham Forest           13
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2021-08-14  17:30  Premier League   Matchweek 1  Sat  Away      W  3.0
# 1   2021-08-21  12:30  Premier League   Matchweek 2  Sat  Home      W  2.0
# 2   2021-08-28  17:30  Premier League   Matchweek 3  Sat  Home      D  1.0
# 3   2021-09-12  16:30  Premier League   Matchweek 4  Sun  Away      W  3.0
# 5   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# 7   2021-09-25  17:30  Premier League   Matchweek 6  Sat  Away      D  3.0
# 9   2021-10-03  16:30  Premier League   Matchweek 7  Sun  Home      D  2.0
# 10  2021-10-16  12:30  Premier League   Matchweek 8  Sat  Away      W  5.0
# 12  2021-10-24  16:30  Premier League   Matchweek 9  Sun  Away      W  5.0
# 14  2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      D  2.0
# 16  2021-11-07  16:30  Premier League  Matchweek 11  Sun  Away      L  2.0
# ...

# %%
matches["round"].value_counts()
# Out:
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 1     40
# Matchweek 2     40
# Matchweek 13    40
# Matchweek 11    40
# Matchweek 6     40
# Matchweek 10    40
# Matchweek 9     40
# Matchweek 3     40
# Matchweek 14    40
# Matchweek 12    38
# Matchweek 8     34
# Matchweek 26    20
# Matchweek 16    20
# Matchweek 23    20
# Matchweek 38    20
# Matchweek 15    20
# Matchweek 34    20
# Matchweek 32    20
# Matchweek 24    20
# Matchweek 30    20
# Matchweek 21    20
# Matchweek 29    20
# Matchweek 37    20
# Matchweek 35    20
# Matchweek 28    20
# Matchweek 25    20
# Matchweek 17    20
# Matchweek 7     20
# Matchweek 27    20
# Matchweek 20    20
# Matchweek 19    20
# Matchweek 31    20
# Matchweek 33    20
# Matchweek 22    20
# Matchweek 36    20
# Matchweek 18    20
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga        opponent  ...  match report  notes    sh  sot  dist   fk   pk  \
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+","", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga        opponent  ...   fk   pk  pkatt  season          team  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           299  93
# 1           163  85

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.47752808988764045

# %%
grouped_matches = matches.set_index("date").groupby(["team"])

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#              time            comp         round  day venue result   gf   ga  \
# date
# 2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0  0.0
# 2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0  0.0
# 2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0  0.0
# 2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0  0.0
# 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0  2.0
# 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0  0.0
# 2021-10-23  17:30  Premier League   Matchweek 9  Sat  Away      W  4.0  1.0
# 2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      L  0.0  2.0
# 2021-11-06  12:30  Premier League  Matchweek 11  Sat  Away      W  2.0  0.0
# 2021-11-21  14:00  Premier League  Matchweek 12  Sun  Home      W  3.0  0.0
# 2021-11-28  14:00  Premier League  Matchweek 13  Sun  Home      W  2.0  1.0
# ...

# %%
matches_rolling = matches.set_index("date").groupby(["team"]).apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                      time            comp         round  day  \
# team                    date
# Arsenal                 2021-08-28  12:30  Premier League   Matchweek 3  Sat
#                         2021-09-11  15:00  Premier League   Matchweek 4  Sat
#                         2021-09-18  15:00  Premier League   Matchweek 5  Sat
#                         2021-09-26  16:30  Premier League   Matchweek 6  Sun
#                         2021-10-02  17:30  Premier League   Matchweek 7  Sat
# ...                                   ...             ...           ...  ...
# Wolverhampton Wanderers 2022-10-08  15:00  Premier League  Matchweek 10  Sat
#                         2022-10-15  15:00  Premier League  Matchweek 11  Sat
#                         2022-10-18  20:15  Premier League  Matchweek 12  Tue
#                         2022-10-23  14:00  Premier League  Matchweek 13  Sun
#                         2022-10-29  15:00  Premier League  Matchweek 14  Sat
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#              time            comp         round  day venue result   gf   ga  \
# date
# 2021-08-28  12:30  Premier League   Matchweek 3  Sat  Away      L  0.0  5.0
# 2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0  0.0
# 2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0  0.0
# 2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0  1.0
# 2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0  0.0
# ...           ...             ...           ...  ...   ...    ...  ...  ...
# 2022-10-08  15:00  Premier League  Matchweek 10  Sat  Away      L  0.0  3.0
# 2022-10-15  15:00  Premier League  Matchweek 11  Sat  Home      W  1.0  0.0
# 2022-10-18  20:15  Premier League  Matchweek 12  Tue  Away      L  1.0  2.0
# 2022-10-23  14:00  Premier League  Matchweek 13  Sun  Home      L  0.0  4.0
# 2022-10-29  15:00  Premier League  Matchweek 14  Sat  Away      D  1.0  1.0
#
# ...

# %%
# matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#       time            comp         round  day venue result   gf   ga  \
# 0    12:30  Premier League   Matchweek 3  Sat  Away      L  0.0  5.0
# 1    15:00  Premier League   Matchweek 4  Sat  Home      W  1.0  0.0
# 2    15:00  Premier League   Matchweek 5  Sat  Away      W  1.0  0.0
# 3    16:30  Premier League   Matchweek 6  Sun  Home      W  3.0  1.0
# 4    17:30  Premier League   Matchweek 7  Sat  Away      D  0.0  0.0
# ..     ...             ...           ...  ...   ...    ...  ...  ...
# 961  15:00  Premier League  Matchweek 10  Sat  Away      L  0.0  3.0
# 962  15:00  Premier League  Matchweek 11  Sat  Home      W  1.0  0.0
# 963  20:15  Premier League  Matchweek 12  Tue  Away      L  1.0  2.0
# 964  14:00  Premier League  Matchweek 13  Sun  Home      L  0.0  4.0
# 965  15:00  Premier League  Matchweek 14  Sat  Away      D  1.0  1.0
#
#             opponent   xg  ...  day_code  target  gf_rolling ga_rolling  \
# ...

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.Dtaframe(dict(actual=test['target'], predicted=preds), index=test.index)
    precision = precision_score(test["target"],preds)
    return combuned, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-286-df5815e4a99e> in <module>
# ...
